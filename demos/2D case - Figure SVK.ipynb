# %% [markdown]
# # 2D case - Figure Saint Venant-Kirchhoff
# Two-parameter 2D problem - Investigation of  the  convergence  of  the  reduced-order model and of the evolution of the size of the reduced-order basis.

# %% [markdown]
# ## Libraries import

# %%
import sys  
import torch
import torch.nn as nn
from neurom.HiDeNN_PDE import MeshNN, NeuROM, MeshNN_2D, MeshNN_1D
import neurom.src.Pre_processing as pre
from neurom.src.PDE_Library import Strain, Stress,VonMises_plain_strain
from neurom.src.Training import Training_NeuROM_multi_level
import neurom.Post.Plots as Pplot
import time
import os
import torch._dynamo as dynamo
from importlib import reload  
import tomllib
import numpy as np
import argparse

torch.manual_seed(9975355953847005664)

# %% [markdown]
# ## Load the config file

# %%
    Configuration_file = 'Configurations/config_2D_ROM_NH.toml'

    with open(Configuration_file, mode="rb") as file:
        config = tomllib.load(file)

# %% [markdown]
# ## Definition of the space domain and mechanical proprieties of the structure
#
# The initial Material parameters, the geometry, mesh and the boundary conditions are set.

# %%
# Overwrites the multi-level training
config["training"]["multiscl_max_refinment"] = 1

# Material parameters definition

Mat = pre.Material(             flag_lame = False,                                  # If True should input lmbda and mu instead of E and nu
                                coef1     = config["material"]["E"],                # Young Modulus
                                coef2     = config["material"]["nu"]                # Poisson's ratio
                )


# Create mesh object
MaxElemSize = pre.ElementSize(
                                dimension     = config["interpolation"]["dimension"],
                                L             = config["geometry"]["L"],
                                order         = config["interpolation"]["order"],
                                np            = config["interpolation"]["np"],
                                MaxElemSize2D = config["interpolation"]["MaxElemSize2D"]
                            )
Excluded = []
Mesh_object = pre.Mesh( 
                                config["geometry"]["Name"],                         # Create the mesh object
                                MaxElemSize, 
                                config["interpolation"]["order"], 
                                config["interpolation"]["dimension"]
                        )

Mesh_object.AddBorders(config["Borders"]["Borders"])
Mesh_object.AddBCs(                                                                 # Include Boundary physical domains infos (BCs+volume)
                                config["geometry"]["Volume_element"],
                                Excluded,
                                config["DirichletDictionryList"]
                    )                   

Mesh_object.MeshGeo()                                                               # Mesh the .geo file if .msh does not exist
Mesh_object.ReadMesh()       
Mesh_object.ExportMeshVtk()
# Out:
#
#
#    _   _            ____   ___  __  __
#   | \ | | ___ _   _|  _ \ / _ \|  \/  |
#   |  \| |/ _ \ | | | |_) | | | | |\/| |
#   | |\  |  __/ |_| |  _ <| |_| | |  | |
#   |_| \_|\___|\__,_|_| \_\ ___/|_|  |_|
#
#                   3.1.2
#
# ************ MESH READING COMPLETE ************
#
#  * Dimension of the problem: 2D
#  * Elements type:            t3: 3-node triangle
#  * Number of Dofs:           224

# %% [markdown]
# ## Parametric study definition
#
# The hypercube describing the parametric domain used for the tensor decomposition is set-up here

# %%
ParameterHypercube = torch.tensor([ [   config["parameters"]["para_1_min"],
                                        config["parameters"]["para_1_max"],
                                        config["parameters"]["N_para_1"]],
                                    [   config["parameters"]["para_2_min"],
                                        config["parameters"]["para_2_max"],
                                        config["parameters"]["N_para_2"]]])

# %% [markdown]
# ## Initialisation of the surrogate model

# %%
ROM_model = NeuROM(                                                                 # Build the surrogate (reduced-order) model
                    Mesh_object, 
                    ParameterHypercube, 
                    config,
                    config["solver"]["n_modes_ini"],
                    config["solver"]["n_modes_max"]
                    )

# %% [markdown]
# ## Training the model

# %%
ROM_model.Freeze_Mesh()                                                             # Set space mesh coordinates as untrainable
ROM_model.Freeze_MeshPara()                                                         # Set parameters mesh coordinates as untrainable

ROM_model.TrainingParameters(   
                                loss_decrease_c = config["training"]["loss_decrease_c"], 
                                Max_epochs = config["training"]["n_epochs"], 
                                learning_rate = config["training"]["learning_rate"]
                            )

ROM_model.train()                                                                   # Put the model in training mode
ROM_model = Training_NeuROM_multi_level(ROM_model,config, Mat)         
# ROM_model,Mesh_object = Training_NeuROM_multi_level(ROM_model,config, Mat)
# Out:
# * Refinement level: 0
#
# **************** START TRAINING ***************
#
# epoch 10 loss = 1.75057e-06 modes = 1
# epoch 20 loss = 1.34384e-06 modes = 1
# epoch 30 loss = 1.04358e-06 modes = 1
# epoch 40 loss = 8.23916e-07 modes = 1
# epoch 50 loss = 6.61838e-07 modes = 1
# epoch 60 loss = 5.39637e-07 modes = 1
# epoch 70 loss = 4.43772e-07 modes = 1
# epoch 80 loss = 3.61649e-07 modes = 1
# epoch 90 loss = 2.77682e-07 modes = 1
# epoch 100 loss = 1.71076e-07 modes = 1
# epoch 110 loss = 1.71956e-08 modes = 1
# epoch 120 loss = -2.08271e-07 modes = 1
# epoch 130 loss = -5.24390e-07 modes = 1
# epoch 140 loss = -9.41115e-07 modes = 1
# epoch 150 loss = -1.45816e-06 modes = 1
# epoch 160 loss = -2.06755e-06 modes = 1
# epoch 170 loss = -2.75922e-06 modes = 1
# epoch 180 loss = -3.52685e-06 modes = 1
# epoch 190 loss = -4.37016e-06 modes = 1
# epoch 200 loss = -5.29277e-06 modes = 1
# epoch 210 loss = -6.29967e-06 modes = 1
# epoch 220 loss = -7.39642e-06 modes = 1
# epoch 230 loss = -8.58999e-06 modes = 1
# epoch 240 loss = -9.89026e-06 modes = 1
# epoch 250 loss = -1.13115e-05 modes = 1
# epoch 260 loss = -1.28738e-05 modes = 1
# epoch 270 loss = -1.46028e-05 modes = 1
# epoch 280 loss = -1.65271e-05 modes = 1
# epoch 290 loss = -1.86767e-05 modes = 1
# epoch 300 loss = -2.10780e-05 modes = 1
# epoch 310 loss = -2.37467e-05 modes = 1
# epoch 320 loss = -2.66803e-05 modes = 1
# epoch 330 loss = -2.98574e-05 modes = 1
# epoch 340 loss = -3.32423e-05 modes = 1
# epoch 350 loss = -3.67945e-05 modes = 1
# epoch 360 loss = -4.04783e-05 modes = 1
# epoch 370 loss = -4.42654e-05 modes = 1
# epoch 380 loss = -4.81307e-05 modes = 1
# epoch 390 loss = -5.20451e-05 modes = 1
# epoch 400 loss = -5.59718e-05 modes = 1
# epoch 410 loss = -5.98688e-05 modes = 1
# epoch 420 loss = -6.3693e-05 modes = 1
# epoch 430 loss = -6.74043e-05 modes = 1
# epoch 440 loss = -7.09665e-05 modes = 1
# epoch 450 loss = -7.43474e-05 modes = 1
# epoch 460 loss = -7.75195e-05 modes = 1
# epoch 470 loss = -8.04621e-05 modes = 1
# epoch 480 loss = -8.31620e-05 modes = 1
# epoch 490 loss = -8.56143e-05 modes = 1
# epoch 500 loss = -8.78216e-05 modes = 1
# epoch 510 loss = -8.97926e-05 modes = 1
# epoch 520 loss = -9.15408e-05 modes = 1
# epoch 530 loss = -9.30830e-05 modes = 1
# epoch 540 loss = -9.44379e-05 modes = 1
# epoch 550 loss = -9.5625e-05 modes = 1
# epoch 560 loss = -9.66634e-05 modes = 1
# epoch 570 loss = -9.75716e-05 modes = 1
# epoch 580 loss = -9.83662e-05 modes = 1
# epoch 590 loss = -9.90625e-05 modes = 1
# epoch 600 loss = -9.96737e-05 modes = 1
# epoch 610 loss = -1.00211e-04 modes = 1
# epoch 620 loss = -1.00685e-04 modes = 1
# epoch 630 loss = -1.01104e-04 modes = 1
# epoch 640 loss = -1.01475e-04 modes = 1
# epoch 650 loss = -1.01803e-04 modes = 1
# epoch 660 loss = -1.02095e-04 modes = 1
# epoch 670 loss = -1.02353e-04 modes = 1
# epoch 680 loss = -1.02583e-04 modes = 1
# epoch 690 loss = -1.02786e-04 modes = 1
# epoch 700 loss = -1.02966e-04 modes = 1
# epoch 710 loss = -1.03126e-04 modes = 1
# epoch 720 loss = -1.03267e-04 modes = 1
# epoch 730 loss = -1.03392e-04 modes = 1
# epoch 740 loss = -1.03502e-04 modes = 1
# epoch 750 loss = -1.03599e-04 modes = 1
# epoch 760 loss = -1.03684e-04 modes = 1
# epoch 770 loss = -1.03759e-04 modes = 1
# epoch 780 loss = -1.03825e-04 modes = 1
# epoch 790 loss = -1.03883e-04 modes = 1
# epoch 800 loss = -1.03934e-04 modes = 1
# epoch 810 loss = -1.03978e-04 modes = 1
# epoch 820 loss = -1.04017e-04 modes = 1
# epoch 830 loss = -1.04051e-04 modes = 1
# epoch 840 loss = -1.04081e-04 modes = 1
# epoch 850 loss = -1.04108e-04 modes = 1
# epoch 860 loss = -1.04131e-04 modes = 1
# epoch 870 loss = -1.04152e-04 modes = 1
# epoch 880 loss = -1.0417e-04 modes = 1
# epoch 890 loss = -1.04186e-04 modes = 1
# epoch 900 loss = -1.042e-04 modes = 1
# epoch 910 loss = -1.04212e-04 modes = 1
# epoch 920 loss = -1.04223e-04 modes = 1
# epoch 930 loss = -1.04234e-04 modes = 2
# epoch 940 loss = -1.04255e-04 modes = 2
# epoch 950 loss = -1.04288e-04 modes = 2
# epoch 960 loss = -1.04344e-04 modes = 2
# epoch 970 loss = -1.04444e-04 modes = 2
# epoch 980 loss = -1.04613e-04 modes = 2
# epoch 990 loss = -1.04879e-04 modes = 2
# epoch 1000 loss = -1.05270e-04 modes = 2
# epoch 1010 loss = -1.05805e-04 modes = 2
# epoch 1020 loss = -1.06489e-04 modes = 2
# epoch 1030 loss = -1.07311e-04 modes = 2
# epoch 1040 loss = -1.08241e-04 modes = 2
# epoch 1050 loss = -1.09236e-04 modes = 2
# epoch 1060 loss = -1.10251e-04 modes = 2
# epoch 1070 loss = -1.1125e-04 modes = 2
# epoch 1080 loss = -1.12212e-04 modes = 2
# epoch 1090 loss = -1.13123e-04 modes = 2
# epoch 1100 loss = -1.13971e-04 modes = 2
# epoch 1110 loss = -1.14755e-04 modes = 2
# epoch 1120 loss = -1.15478e-04 modes = 2
# epoch 1130 loss = -1.16149e-04 modes = 2
# epoch 1140 loss = -1.16774e-04 modes = 2
# epoch 1150 loss = -1.17359e-04 modes = 2
# epoch 1160 loss = -1.1791e-04 modes = 2
# epoch 1170 loss = -1.1843e-04 modes = 2
# epoch 1180 loss = -1.18921e-04 modes = 2
# epoch 1190 loss = -1.19386e-04 modes = 2
# epoch 1200 loss = -1.19827e-04 modes = 2
# epoch 1210 loss = -1.20244e-04 modes = 2
# epoch 1220 loss = -1.20639e-04 modes = 2
# epoch 1230 loss = -1.21013e-04 modes = 2
# epoch 1240 loss = -1.21365e-04 modes = 2
# epoch 1250 loss = -1.21698e-04 modes = 2
# epoch 1260 loss = -1.22012e-04 modes = 2
# epoch 1270 loss = -1.22307e-04 modes = 2
# epoch 1280 loss = -1.22585e-04 modes = 2
# epoch 1290 loss = -1.22846e-04 modes = 2
# epoch 1300 loss = -1.23091e-04 modes = 2
# epoch 1310 loss = -1.23321e-04 modes = 2
# epoch 1320 loss = -1.23537e-04 modes = 2
# epoch 1330 loss = -1.2374e-04 modes = 2
# epoch 1340 loss = -1.23929e-04 modes = 2
# epoch 1350 loss = -1.24107e-04 modes = 2
# epoch 1360 loss = -1.24274e-04 modes = 2
# epoch 1370 loss = -1.2443e-04 modes = 2
# epoch 1380 loss = -1.24576e-04 modes = 2
# epoch 1390 loss = -1.24713e-04 modes = 2
# epoch 1400 loss = -1.24841e-04 modes = 2
# epoch 1410 loss = -1.24962e-04 modes = 2
# epoch 1420 loss = -1.25074e-04 modes = 2
# epoch 1430 loss = -1.25180e-04 modes = 2
# epoch 1440 loss = -1.25279e-04 modes = 2
# epoch 1450 loss = -1.25372e-04 modes = 2
# epoch 1460 loss = -1.25459e-04 modes = 2
# epoch 1470 loss = -1.25541e-04 modes = 2
# epoch 1480 loss = -1.25617e-04 modes = 2
# epoch 1490 loss = -1.25689e-04 modes = 2
# epoch 1500 loss = -1.25756e-04 modes = 2
# epoch 1510 loss = -1.2582e-04 modes = 2
# epoch 1520 loss = -1.25879e-04 modes = 2
# epoch 1530 loss = -1.25935e-04 modes = 2
# epoch 1540 loss = -1.25987e-04 modes = 2
# epoch 1550 loss = -1.26036e-04 modes = 2
# epoch 1560 loss = -1.26083e-04 modes = 2
# epoch 1570 loss = -1.26126e-04 modes = 2
# epoch 1580 loss = -1.26167e-04 modes = 2
# epoch 1590 loss = -1.26205e-04 modes = 2
# epoch 1600 loss = -1.26241e-04 modes = 2
# epoch 1610 loss = -1.26275e-04 modes = 2
# epoch 1620 loss = -1.26307e-04 modes = 2
# epoch 1630 loss = -1.26338e-04 modes = 2
# epoch 1640 loss = -1.26366e-04 modes = 2
# epoch 1650 loss = -1.26393e-04 modes = 2
# epoch 1660 loss = -1.26418e-04 modes = 2
# epoch 1670 loss = -1.26442e-04 modes = 2
# epoch 1680 loss = -1.26465e-04 modes = 2
# epoch 1690 loss = -1.26486e-04 modes = 2
# epoch 1700 loss = -1.26507e-04 modes = 2
# epoch 1710 loss = -1.26526e-04 modes = 2
# epoch 1720 loss = -1.26544e-04 modes = 2
# epoch 1730 loss = -1.26561e-04 modes = 2
# epoch 1740 loss = -1.26577e-04 modes = 2
# epoch 1750 loss = -1.26592e-04 modes = 2
# epoch 1760 loss = -1.26607e-04 modes = 2
# epoch 1770 loss = -1.26621e-04 modes = 2
# epoch 1780 loss = -1.26633e-04 modes = 2
# epoch 1790 loss = -1.26644e-04 modes = 3
# *************** END FIRST PHASE ***************
#
# * Training time: 19.81533718109131s
# * Saving time: 1.9073486328125e-06s
# * Evaluation time: 14.035396099090576s
# * Backward time: 5.469231367111206s
# * Update time: 0.22831940650939941s
# * Average epoch time: 0.011039185059103793s
# ************** START SECOND PAHSE *************
#
# epoch 5 loss = -1.2665e-04
# *************** END OF TRAINING ***************
#
# * Training time: 19.97395420074463s

# %% [markdown]
# ## Plotting area
#
# Reproducing figure 8, a-b-c

# %%
tikz = False

import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import matplotlib
plt.rcParams['text.usetex'] = False

Modes_flag = ROM_model.training_recap["Mode_vect"]
error = ROM_model.training_recap["Loss_vect"]
decay = ROM_model.training_recap["Loss_decrease_vect"]
threshold = config["training"]["loss_decrease_c"]

name = 'FigSVKa'


# plot Fig 8a

fig = plt.figure()
ax = fig.add_subplot(111)

## First curve
ax.invert_yaxis()
g1 = ax.semilogy(-torch.tensor(error), color='#01426A')
ax.set_ylabel(r'$ - J\left(u\left(x\right)\right)$',color='#01426A')
ax.tick_params(axis='y', colors='#01426A', which='both')
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.set_xlabel(r'Epochs')

## Second curve
ax2 = ax.twinx()
g2 = ax2.plot(Modes_flag, color='#CE0037')
ax2.set_ylabel(r'$m$',color='#CE0037')
ax2.tick_params(axis='y', colors='#CE0037')
ax2.yaxis.set_major_locator(MaxNLocator(integer=True))
ax.grid()

if tikz:
    import tikzplotlib
    tikzplotlib.save('Results/'+name+'_zoom.tex')
plt.savefig('Results/'+name+'_zoom.pdf', transparent=True, bbox_inches = "tight")

plt.show() 
plt.clf() 





name = 'FigSVKb'

# pre processing for padding and zooming on epochs after rough training during the first epochs
Zoom_depth = np.min(np.where(np.array(Modes_flag) == np.array(Modes_flag)[0]+1))
Zoom_start_index = int(np.floor(0.9*Zoom_depth))
second_stages_epochs = len(error) - len(Modes_flag)
Modes_flag.extend([Modes_flag[-1]]*second_stages_epochs)
x_indexes = np.arange(len(Modes_flag[Zoom_start_index:]))+Zoom_start_index

# plot Fig 8b

fig = plt.figure()
ax = fig.add_subplot(111)

## First curve
ax.invert_yaxis()
g1 = ax.semilogy(x_indexes,-torch.tensor(error[Zoom_start_index:]), color='#01426A')
ax.set_ylabel(r'$ - J\left(u\left(x\right)\right)$',color='#01426A')
ax.tick_params(axis='y', colors='#01426A', which='both')
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.set_xlabel(r'Epochs')

## Second curve
ax2 = ax.twinx()
g2 = ax2.plot(x_indexes,Modes_flag[Zoom_start_index:], color='#CE0037')
ax2.set_ylabel(r'$m$',color='#CE0037')
ax2.tick_params(axis='y', colors='#CE0037')
ax2.yaxis.set_major_locator(MaxNLocator(integer=True))
ax.grid()

if tikz:
    import tikzplotlib
    tikzplotlib.save('Results/'+name+'_zoom.tex')
plt.savefig('Results/'+name+'_zoom.pdf', transparent=True, bbox_inches = "tight")

plt.show() 
plt.clf() 


name = 'FigSVKc'

# plot Fig 8c

ax = plt.gca()
ax.semilogy(decay,color='#01426A')
ax.tick_params(axis='y', colors='#01426A')
ax.set_ylabel(r'd log($J\left(u\left(x\right)\right)$)',color='#01426A')
plt.axhline(threshold,color = 'k')
ax.xaxis.set_major_locator(MaxNLocator(integer=True))


# plt.ylim((0.01,20))
ax2 = plt.gca().twinx()
ax2.plot(Modes_flag,color='#CE0037')
ax2.set_ylabel(r'$m$',color='#CE0037')
ax2.tick_params(axis='y', colors='#CE0037')
ax2.yaxis.set_major_locator(MaxNLocator(integer=True))
ax.grid()

if tikz:
    import tikzplotlib
    tikzplotlib.save('Results/'+name+'.tex')
plt.savefig('Results/'+name+'.pdf', transparent=True, bbox_inches = "tight")
plt.show() 

plt.clf()

# %% [markdown]
# ## Export plot data
# The data are saved in a ```csv``` file so that they can be plotted in the article using pgfplot.

# %%
import pandas as pd
epochs = list(range(len(Modes_flag)))
N = len(decay)
Name = "FigSVK"

df_full = pd.DataFrame(np.stack((epochs[:N],decay[:N],Modes_flag[:N],(-torch.tensor(error)[:N]).tolist()) ,axis=1), columns=['epochs', 'Decay','Modes',"Loss"])
df_truncated = pd.DataFrame(np.stack((Modes_flag[Zoom_start_index:],(-torch.tensor(error)[Zoom_start_index:]).tolist(), epochs[Zoom_start_index:]) ,axis=1), columns=["Modes_truncated","Loss_truncated","epochs_truncated"])
df_combined = pd.concat([df_full, df_truncated], axis=1)
df_combined = df_combined.astype('float64')
df_combined.to_csv('Results/'+Name+'.csv')
